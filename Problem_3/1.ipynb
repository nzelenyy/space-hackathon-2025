# %%
from tqdm import tqdm

from src.image_works import read_image, show_image, generate_combined_noise, generate_perlin_noise, generate_deffected_pixels, save_image_to_file, generate_clouds

# %%
width = 2000
height = 2000

# %% [markdown]
# Считаем файлы images/film

# %%
# Пример использования
clouds = generate_clouds(width=2200, height=2200, scale=200, threshold=180)
show_image(clouds)

# %%
film_images_orig = []
for i in range(1, 11):
    file_name = f'problem_data/images/film/{i}.txt'
    im = read_image(file_name)
    film_images_orig.append(im)
    #show_image(im)
# Out:
# Image shape: (2000, 2000)
# Image shape: (2000, 2000)
# Image shape: (2000, 2000)
# Image shape: (2000, 2000)
# Image shape: (2000, 2000)
# Image shape: (2000, 2000)
# Image shape: (2000, 2000)
# Image shape: (2000, 2000)
# Image shape: (2000, 2000)
# Image shape: (2000, 2000)

# %%
im1 = generate_combined_noise(width, height)
show_image(im1)

# %%
show_image( im1 +clouds[0:2000, 0:2000])

# %%
a = generate_deffected_pixels(film_images_orig[0]+im1)
show_image(a)
